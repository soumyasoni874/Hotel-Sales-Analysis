# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\win 10\\Downloads\\Hotel.csv")
df
# Out:
#              ID  n_adults  n_children  weekend_nights  week_nights  \
# 0      INN00001         2           0               1            2
# 1      INN00002         2           0               2            3
# 2      INN00003         1           0               2            1
# 3      INN00004         2           0               0            2
# 4      INN00005         2           0               1            1
# ...         ...       ...         ...             ...          ...
# 36270  INN36271         3           0               2            6
# 36271  INN36272         2           0               1            3
# 36272  INN36273         2           0               2            6
# 36273  INN36274         2           0               0            3
# 36274  INN36275         2           0               1            2
#
#           meal_plan  car_parking_space    room_type  lead_time  year  month  \
# 0       Meal Plan 1                  0  Room_Type 1        224  2017     10
# ...

# %%
df.columns
# Out:
# Index(['ID', 'n_adults', 'n_children', 'weekend_nights', 'week_nights',
#        'meal_plan', 'car_parking_space', 'room_type', 'lead_time', 'year',
#        'month', 'date', 'market_segment', 'repeated_guest',
#        'previous_cancellations', 'previous_bookings_not_canceled',
#        'avg_room_price', 'special_requests', 'status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              36275 non-null  object
#  1   n_adults                        36275 non-null  int64
#  2   n_children                      36275 non-null  int64
#  3   weekend_nights                  36275 non-null  int64
#  4   week_nights                     36275 non-null  int64
#  5   meal_plan                       36275 non-null  object
#  6   car_parking_space               36275 non-null  int64
#  7   room_type                       36275 non-null  object
#  8   lead_time                       36275 non-null  int64
#  9   year                            36275 non-null  int64
#  10  month                           36275 non-null  int64
#  11  date                            36275 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                                0
# n_adults                          0
# n_children                        0
# weekend_nights                    0
# week_nights                       0
# meal_plan                         0
# car_parking_space                 0
# room_type                         0
# lead_time                         0
# year                              0
# month                             0
# date                              0
# market_segment                    0
# repeated_guest                    0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# avg_room_price                    0
# special_requests                  0
# status                            0
# dtype: int64

# %%
df.drop(['previous_bookings_not_canceled','previous_cancellations'],axis=1,inplace=True)

# %%
df
# Out:
#              ID  n_adults  n_children  weekend_nights  week_nights  \
# 0      INN00001         2           0               1            2
# 1      INN00002         2           0               2            3
# 2      INN00003         1           0               2            1
# 3      INN00004         2           0               0            2
# 4      INN00005         2           0               1            1
# ...         ...       ...         ...             ...          ...
# 36270  INN36271         3           0               2            6
# 36271  INN36272         2           0               1            3
# 36272  INN36273         2           0               2            6
# 36273  INN36274         2           0               0            3
# 36274  INN36275         2           0               1            2
#
#           meal_plan  car_parking_space    room_type  lead_time  year  month  \
# 0       Meal Plan 1                  0  Room_Type 1        224  2017     10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 36275 non-null  object
#  1   n_adults           36275 non-null  int64
#  2   n_children         36275 non-null  int64
#  3   weekend_nights     36275 non-null  int64
#  4   week_nights        36275 non-null  int64
#  5   meal_plan          36275 non-null  object
#  6   car_parking_space  36275 non-null  int64
#  7   room_type          36275 non-null  object
#  8   lead_time          36275 non-null  int64
#  9   year               36275 non-null  int64
#  10  month              36275 non-null  int64
#  11  date               36275 non-null  int64
#  12  market_segment     36275 non-null  object
#  13  repeated_guest     36275 non-null  int64
#  14  status             36275 non-null  object
# dtypes: int64(10), object(5)
# memory usage: 4.2+ MB

# %%
df.describe()
# Out:
#            n_adults    n_children  weekend_nights   week_nights  \
# count  36275.000000  36275.000000    36275.000000  36275.000000
# mean       1.844962      0.105279        0.810724      2.204300
# std        0.518715      0.402648        0.870644      1.410905
# min        0.000000      0.000000        0.000000      0.000000
# 25%        2.000000      0.000000        0.000000      1.000000
# 50%        2.000000      0.000000        1.000000      2.000000
# 75%        2.000000      0.000000        2.000000      3.000000
# max        4.000000     10.000000        7.000000     17.000000
#
#        car_parking_space     lead_time          year         month  \
# count       36275.000000  36275.000000  36275.000000  36275.000000
# mean            0.030986     85.232557   2017.820427      7.423653
# std             0.173281     85.930817      0.383836      3.069894
# min             0.000000      0.000000   2017.000000      1.000000
# ...

# %%
df.head()
# Out:
#          ID  n_adults  n_children  weekend_nights  week_nights     meal_plan  \
# 0  INN00001         2           0               1            2   Meal Plan 1
# 1  INN00002         2           0               2            3  Not Selected
# 2  INN00003         1           0               2            1   Meal Plan 1
# 3  INN00004         2           0               0            2   Meal Plan 1
# 4  INN00005         2           0               1            1  Not Selected
#
#    car_parking_space    room_type  lead_time  year  month  date  \
# 0                  0  Room_Type 1        224  2017     10     2
# 1                  0  Room_Type 1          5  2018     11     6
# 2                  0  Room_Type 1          1  2018      2    28
# 3                  0  Room_Type 1        211  2018      5    20
# 4                  0  Room_Type 1         48  2018      4    11
#
#   market_segment  repeated_guest        status
# 0        Offline               0  Not_Canceled
# ...

# %%
df.tail()
# Out:
#              ID  n_adults  n_children  weekend_nights  week_nights  \
# 36270  INN36271         3           0               2            6
# 36271  INN36272         2           0               1            3
# 36272  INN36273         2           0               2            6
# 36273  INN36274         2           0               0            3
# 36274  INN36275         2           0               1            2
#
#           meal_plan  car_parking_space    room_type  lead_time  year  month  \
# 36270   Meal Plan 1                  0  Room_Type 4         85  2018      8
# 36271   Meal Plan 1                  0  Room_Type 1        228  2018     10
# 36272   Meal Plan 1                  0  Room_Type 1        148  2018      7
# 36273  Not Selected                  0  Room_Type 1         63  2018      4
# 36274   Meal Plan 1                  0  Room_Type 1        207  2018     12
#
#        date market_segment  repeated_guest        status
# ...

# %%
total_amount=df['repeated_guest'].count()
print('Total repeated_guest:{repeated_guest}')
# Out:
# Total repeated_guest:{repeated_guest}

# %%
df
# Out:
#              ID  n_adults  n_children  weekend_nights  week_nights  \
# 0      INN00001         2           0               1            2
# 1      INN00002         2           0               2            3
# 2      INN00003         1           0               2            1
# 3      INN00004         2           0               0            2
# 4      INN00005         2           0               1            1
# ...         ...       ...         ...             ...          ...
# 36270  INN36271         3           0               2            6
# 36271  INN36272         2           0               1            3
# 36272  INN36273         2           0               2            6
# 36273  INN36274         2           0               0            3
# 36274  INN36275         2           0               1            2
#
#           meal_plan  car_parking_space    room_type  lead_time  year  month  \
# 0       Meal Plan 1                  0  Room_Type 1        224  2017     10
# ...
